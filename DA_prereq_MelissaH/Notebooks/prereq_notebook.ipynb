# %% [markdown]
# Hello. My name is Melissa Haertzen. I am 40 years old and a single mother to 3 children. I have attemped the Data Analysis class on Coursera twice now and have dropped out halfway through due to difficulty learning without an instructor and being able to ask questions. I am hopeful that code you will be the DA class that sticks for me as I have already learned more than I absorbed from Coursera. I have the majority of my work experience as an Accounting Clerk and in retail. My goal with taking this course is to create a higher earning ability for myself so I can better provide for my children. I am excited to learn what I can and look forward to using the skills I aquire in a profitable career path.

# %%
print ("Hello, Earth");
# Out:
# Hello, Earth
